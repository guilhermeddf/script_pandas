# %%
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/guilhermeddf/icse_paper/master/icse_paper/datasets/RQ3_RQ4_DataSet.csv?token=AD2KKMQ2WWQSAUJURTFLOBC6F4UT6')
lang = pd.read_csv('final_df.csv')
linguagens = lang.project
#type(linguagens)
#linguagens
# Out:
# 0          osmlab/atlas-generator
# 1       ressec/hemajoo-foundation
# 2         apache/incubator-tamaya
# 3           SonarSource/sonarqube
# 4           gurkenlabs/litiengine
#                  ...
# 92       itsallcode/openfasttrace
# 93             try0/wicket-toastr
# 94    coffeenet/coffeenet-starter
# 95                symonk/sylenium
# 96             NoticeMeDan/cinema
# Name: project, Length: 97, dtype: object

# %%
dataset = dataset[dataset['project'].isin(linguagens)]

# %%
dataset.to_csv('dataset_modelo.csv')

# %%
# Out:
#      ccq_builds_in_sonar_period          sonar_start_date  \
# 3                           352  2018-07-31T07:51:30+0200
# 4                           120  2019-03-26T18:56:26+0100
# 5                           136  2019-04-21T22:40:53+0200
# 8                           344  2018-10-11T09:54:56+0200
# 9                           344  2017-09-09T14:38:05+0200
# ..                          ...                       ...
# 176                          32  2018-11-18T10:20:30+0100
# 177                          40  2018-12-12T11:52:04+0100
# 178                          72  2019-02-01T13:13:44+0100
# 181                         112  2018-10-23T19:27:08+0200
# 183                          64  2017-12-06T19:18:52+0100
#
#                sonar_end_date  sonar_duration                      project  \
# 3    2019-07-22T19:52:44+0200             356       osmlab/atlas-generator
# 4    2019-07-30T01:05:39+0200             125    ressec/hemajoo-foundation
# ...
